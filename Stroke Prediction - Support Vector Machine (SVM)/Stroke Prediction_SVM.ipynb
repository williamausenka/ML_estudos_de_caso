# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
raw_data = pd.read_csv('healthcare-dataset-stroke-data.csv')

# %%
raw_data
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
raw_data.isnull().any()
# Out:
# id                   False
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# Residence_type       False
# avg_glucose_level    False
# bmi                   True
# smoking_status       False
# stroke               False
# dtype: bool

# %%
data_noNull = raw_data.copy()

# %%
data_noNull = raw_data.dropna()

# %%
data_noNull.isnull().any()
# Out:
# id                   False
# gender               False
# age                  False
# hypertension         False
# heart_disease        False
# ever_married         False
# work_type            False
# Residence_type       False
# avg_glucose_level    False
# bmi                  False
# smoking_status       False
# stroke               False
# dtype: bool

# %%
data_noNull
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# 5     56669    Male  81.0             0              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5104  14180  Female  13.0             0              0           No
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#################################################### EDA ##########################################################

# %%
sns.histplot(data_noNull['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
data_noNull['age'].mean()
# Out:
# 42.865373803218596

# %%
sns.countplot(data_noNull['gender'])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['age'],hue=data_noNull['gender'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['age'],hue=data_noNull['hypertension'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['age'],hue=data_noNull['heart_disease'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['age'],hue=data_noNull['smoking_status'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['age'],hue=data_noNull['work_type'])
plt.legend(bbox_to_anchor=(1.03, 1), loc=2, borderaxespad=0.)

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['age'],hue=data_noNull['Residence_type'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['avg_glucose_level'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='avg_glucose_level'>

# %%
sns.barplot(x=data_noNull['stroke'],y=data_noNull['avg_glucose_level'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='avg_glucose_level'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['bmi'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='bmi'>

# %%
sns.countplot(data_noNull['ever_married'], hue=data_noNull['stroke'])
# Out:
# D:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ever_married', ylabel='count'>

# %%
sns.boxplot(x=data_noNull['stroke'],y=data_noNull['age'],hue=data_noNull['ever_married'])
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='age'>

# %%
data_noNull['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
data_noNull['ever_married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data_noNull['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
data_noNull['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
data_noNull['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
################################################## SVM IMPLEMENTATION #############################################

# %%
data_dum = data_noNull.copy()

# %%
gender_column = pd.get_dummies(data_dum['gender'], drop_first = True)
gender_column
# Out:
#       Male  Other
# 0        1      0
# 2        1      0
# 3        0      0
# 4        0      0
# 5        1      0
# ...    ...    ...
# 5104     0      0
# 5106     0      0
# 5107     0      0
# 5108     1      0
# 5109     0      0
#
# [4909 rows x 2 columns]

# %%
everMarried_column = pd.get_dummies(data_dum['ever_married'], drop_first = True)
everMarried_column
# Out:
#       Yes
# 0       1
# 2       1
# 3       1
# 4       1
# 5       1
# ...   ...
# 5104    0
# 5106    1
# 5107    1
# 5108    1
# 5109    1
#
# [4909 rows x 1 columns]

# %%
workType_column = pd.get_dummies(data_dum['work_type'], drop_first = True)
workType_column
# Out:
#       Never_worked  Private  Self-employed  children
# 0                0        1              0         0
# 2                0        1              0         0
# 3                0        1              0         0
# 4                0        0              1         0
# 5                0        1              0         0
# ...            ...      ...            ...       ...
# 5104             0        0              0         1
# 5106             0        0              1         0
# 5107             0        0              1         0
# 5108             0        1              0         0
# 5109             0        0              0         0
#
# [4909 rows x 4 columns]

# %%
residenceType_column = pd.get_dummies(data_dum['Residence_type'], drop_first = True)
residenceType_column
# Out:
#       Urban
# 0         1
# 2         0
# 3         1
# 4         0
# 5         1
# ...     ...
# 5104      0
# 5106      1
# 5107      0
# 5108      0
# 5109      1
#
# [4909 rows x 1 columns]

# %%
smokingStatus_column = pd.get_dummies(data_dum['smoking_status'], drop_first = True)
smokingStatus_column
# Out:
#       formerly smoked  never smoked  smokes
# 0                   1             0       0
# 2                   0             1       0
# 3                   0             0       1
# 4                   0             1       0
# 5                   1             0       0
# ...               ...           ...     ...
# 5104                0             0       0
# 5106                0             1       0
# 5107                0             1       0
# 5108                1             0       0
# 5109                0             0       0
#
# [4909 rows x 3 columns]

# %%
data_dum = data_dum.drop(['id', 'gender', 'work_type', 'Residence_type', 'smoking_status', 'ever_married'], axis=1)
data_dum
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  stroke
# 0     67.0             0              1             228.69  36.6       1
# 2     80.0             0              1             105.92  32.5       1
# 3     49.0             0              0             171.23  34.4       1
# 4     79.0             1              0             174.12  24.0       1
# 5     81.0             0              0             186.21  29.0       1
# ...    ...           ...            ...                ...   ...     ...
# 5104  13.0             0              0             103.08  18.6       0
# 5106  81.0             0              0             125.20  40.0       0
# 5107  35.0             0              0              82.99  30.6       0
# 5108  51.0             0              0             166.29  25.6       0
# 5109  44.0             0              0              85.28  26.2       0
#
# [4909 rows x 6 columns]

# %%
data_dum = pd.concat([data_dum,gender_column,everMarried_column, workType_column, residenceType_column, smokingStatus_column],axis=1)
data_dum
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  stroke  \
# 0     67.0             0              1             228.69  36.6       1
# 2     80.0             0              1             105.92  32.5       1
# 3     49.0             0              0             171.23  34.4       1
# 4     79.0             1              0             174.12  24.0       1
# 5     81.0             0              0             186.21  29.0       1
# ...    ...           ...            ...                ...   ...     ...
# 5104  13.0             0              0             103.08  18.6       0
# 5106  81.0             0              0             125.20  40.0       0
# 5107  35.0             0              0              82.99  30.6       0
# 5108  51.0             0              0             166.29  25.6       0
# 5109  44.0             0              0              85.28  26.2       0
#
#       Male  Other  Yes  Never_worked  Private  Self-employed  children  Urban  \
# ...

# %%
data_dum.columns.values
# Out:
# array(['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi',
#        'stroke', 'Male', 'Other', 'Yes', 'Never_worked', 'Private',
#        'Self-employed', 'children', 'Urban', 'formerly smoked',
#        'never smoked', 'smokes'], dtype=object)

# %%
columns_names = [
    'age', 'hypertension', 'heart_disease',
       'avg_glucose_level', 'bmi', 'Male', 'Other', 'Yes',
       'Never_worked', 'Private', 'Self-employed', 'children', 'Urban',
       'formerly smoked', 'never smoked', 'smokes','stroke'
]

# %%
data_dum = data_dum[columns_names]
data_dum
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  Male  Other  \
# 0     67.0             0              1             228.69  36.6     1      0
# 2     80.0             0              1             105.92  32.5     1      0
# 3     49.0             0              0             171.23  34.4     0      0
# 4     79.0             1              0             174.12  24.0     0      0
# 5     81.0             0              0             186.21  29.0     1      0
# ...    ...           ...            ...                ...   ...   ...    ...
# 5104  13.0             0              0             103.08  18.6     0      0
# 5106  81.0             0              0             125.20  40.0     0      0
# 5107  35.0             0              0              82.99  30.6     0      0
# 5108  51.0             0              0             166.29  25.6     1      0
# 5109  44.0             0              0              85.28  26.2     0      0
#
# ...

# %%
inputs = data_dum.iloc[:,:-1]
inputs
# Out:
#        age  hypertension  heart_disease  avg_glucose_level   bmi  Male  Other  \
# 0     67.0             0              1             228.69  36.6     1      0
# 2     80.0             0              1             105.92  32.5     1      0
# 3     49.0             0              0             171.23  34.4     0      0
# 4     79.0             1              0             174.12  24.0     0      0
# 5     81.0             0              0             186.21  29.0     1      0
# ...    ...           ...            ...                ...   ...   ...    ...
# 5104  13.0             0              0             103.08  18.6     0      0
# 5106  81.0             0              0             125.20  40.0     0      0
# 5107  35.0             0              0              82.99  30.6     0      0
# 5108  51.0             0              0             166.29  25.6     1      0
# 5109  44.0             0              0              85.28  26.2     0      0
#
# ...

# %%
target = data_dum.iloc[:,-2:]
target = target.drop(['smokes'],axis=1)
target
# Out:
#       stroke
# 0          1
# 2          1
# 3          1
# 4          1
# 5          1
# ...      ...
# 5104       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [4909 rows x 1 columns]

# %%
data_dum.stroke.value_counts()
# Out:
# 0    4700
# 1     209
# Name: stroke, dtype: int64

# %%
#################################### BALANCED #######################################

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
x_train2,x_test2,y_train2,y_test2 = train_test_split(inputs, target, train_size=0.8 , shuffle=True, random_state=20)



from imblearn.over_sampling import SMOTE
SMOTE = SMOTE()
x_train_smote,y_train_smote = SMOTE.fit_resample(x_train2,y_train2)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x_train_smote, y_train_smote, train_size=0.8 , shuffle=True, random_state=20)

# %%
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import RandomUnderSampler 
steps = [('under', RandomUnderSampler()), ('model',SVC())]
pipeline = Pipeline(steps=steps)

# %%
oned_Y_train = np.ravel(Y_train)
pipeline.fit(X_train,oned_Y_train)
# Out:
# Pipeline(steps=[('under', RandomUnderSampler()), ('model', SVC())])

# %%
pipeline_pred = pipeline.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy_score(Y_test,pipeline_pred)
# Out:
# 0.7543160690571049

# %%
print(classification_report(Y_test,pipeline_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.72      0.74       749
#            1       0.74      0.79      0.76       757
#
#     accuracy                           0.75      1506
#    macro avg       0.76      0.75      0.75      1506
# weighted avg       0.76      0.75      0.75      1506

# %%
confusion_matrix(Y_test, pipeline_pred)
# Out:
# array([[539, 210],
#        [160, 597]], dtype=int64)
